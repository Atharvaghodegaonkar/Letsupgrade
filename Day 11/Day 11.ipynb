# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
df = pd.read_csv('general_data.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ### For all the condition check value of alpha is 0.5

# %% [markdown]
# * We will check all the continues features and there relation between attrition
# * If there is relation then print r value and if there is no relation print the statement
# * For all the cases the
# * H0: There is no relation
# * H1 : There is realtion between two variable

# %%
list_two_check = ['Age' , 'DistanceFromHome' , 'MonthlyIncome' , 'PercentSalaryHike' , 'MonthlyIncome' , 'TrainingTimesLastYear' , 'YearsAtCompany', 'YearsSinceLastPromotion' , 'YearsWithCurrManager']
for i in list_two_check :
    stats,P = pearsonr(df['Attrition'] , df[i])
    if P >= 0.05:
        print('There is no corelation between attrition and {}'.format(i))
    else :
        if stats < 0 :
            print('There is negitive relation between {} and {} and r is {}'.format('Attrition' , i , stats))
        else :
            print('There is positive relation between {} and {} and r is {}'.format('Attrition' , i , stats))
# Out:
# There is negitive relation between Attrition and Age and r is -0.1592050068657796
# There is no corelation between attrition and DistanceFromHome
# There is negitive relation between Attrition and MonthlyIncome and r is -0.031176281698115017
# There is positive relation between Attrition and PercentSalaryHike and r is 0.032532594891053514
# There is negitive relation between Attrition and MonthlyIncome and r is -0.031176281698115017
# There is negitive relation between Attrition and TrainingTimesLastYear and r is -0.04943057624425504
# There is negitive relation between Attrition and YearsAtCompany and r is -0.13439221398997717
# There is negitive relation between Attrition and YearsSinceLastPromotion and r is -0.03301877514258439
# There is negitive relation between Attrition and YearsWithCurrManager and r is -0.15619931590162842
